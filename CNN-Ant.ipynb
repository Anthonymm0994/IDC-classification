# %%
# IDC-classification
#from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, SeparableConv2D, BatchNormalization, LeakyReLU

import numpy as np

#if you set this here, then every time you can initiate the model with the same weights
np.random.seed(2016)  

#keras.backend.clear_session()

#5547 images
#load images of shape (5547, 50, 50, 3)
x_images = np.load('/Users/antho/Documents/BreastHistologyImages/X.npy') 
y_images = np.load('/Users/antho/Documents/BreastHistologyImages/Y.npy') 

#sorting 80% of data for training and 20% for testing
x_train = x_images[0:int(len(x_images)*0.8)]
y_train = y_images[0:int(len(y_images)*0.8)]

x_test = x_images[int(len(x_images)*0.8):]
y_test = y_images[int(len(y_images)*0.8):]

#correctly displays image
#plt.imshow(x_images[0])
#plt.show()

#double checking that there's the correct number of images in all data sets
# print(x_train.shape)
# print(y_train.shape)
# print(x_test.shape)
# print(y_test.shape)

#one-hot encode target column
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

#create model
model = Sequential()

# CONV => RELU => POOL
model.add(SeparableConv2D(32, (1, 1), padding="same", input_shape=(50,50,3)))
model.add(LeakyReLU(alpha=0.3))
model.add(BatchNormalization(axis=1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# (CONV => RELU => POOL) * 2
model.add(SeparableConv2D(64, (1, 1), padding="same"))
model.add(LeakyReLU(alpha=0.3))
model.add(BatchNormalization(axis=1))
model.add(SeparableConv2D(64, (1, 1), padding="same"))
model.add(LeakyReLU(alpha=0.3))
model.add(BatchNormalization(axis=1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# (CONV => RELU => POOL) * 3
model.add(SeparableConv2D(128, (1, 1), padding="same"))
model.add(LeakyReLU(alpha=0.3))
model.add(BatchNormalization(axis=1))
model.add(SeparableConv2D(128, (1, 1), padding="same"))
model.add(LeakyReLU(alpha=0.3))
model.add(BatchNormalization(axis=1))
model.add(SeparableConv2D(128, (1, 1), padding="same"))
model.add(LeakyReLU(alpha=0.3))
model.add(BatchNormalization(axis=1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
#model.add(Dropout(0.25))
model.add(Dense(2, activation='softmax'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#train the model
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10)
# Out:
# Using TensorFlow backend.
# Train on 4437 samples, validate on 1110 samples
# Epoch 1/100
# 4437/4437 [==============================] - 25s 6ms/step - loss: 0.8207 - accuracy: 0.6281 - val_loss: 0.4450 - val_accuracy: 1.0000
# Epoch 2/100
# 2112/4437 [=============>................] - ETA: 12s - loss: 0.6925 - accuracy: 0.6723
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-677ef3845a20> in <module>
#      79
#      80 #train the model
# ---> 81 model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
# ...
